# %%
import numpy as np
import cv2
import os
from PIL import Image
import glob
import random

# %%
def fill(img, h, w):
        img = cv2.resize(img, (h, w), cv2.INTER_CUBIC)
        return img
    
def horizontal_shift(img, ratio=0.0):
        if ratio > 1 or ratio < 0:
            
            return img
        ratio = random.uniform(-ratio, ratio)
        h, w = img.shape[:2]
        to_shift = w*ratio
        if ratio > 0:
            img = img[:, :int(w-to_shift), :]
        if ratio < 0:
            img = img[:, int(-1*to_shift):, :]
        img = fill(img, h, w)
        return img

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/red/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_horizontal = horizontal_shift(img, 0.7)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\red\\"+img_name+'_horizontal.jpg',img_horizontal)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/pink/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_horizontal = horizontal_shift(img, 0.7)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
    
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\pink\\"+img_name+'_horizontal.jpg',img_horizontal)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/white/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_horizontal = horizontal_shift(img, 0.7)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
    
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\white\\"+img_name+'_horizontal.jpg',img_horizontal)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/wrong/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_horizontal = horizontal_shift(img, 0.7)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
    
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\wrong\\"+img_name+'_horizontal.jpg',img_horizontal)

# %%
def fill(img, h, w):
    img = cv2.resize(img, (h, w), cv2.INTER_CUBIC)
    return img
def vertical_shift(img, ratio=0.0):
    if ratio > 1 or ratio < 0:
        #print('Value should be less than 1 and greater than 0')
        return img
    ratio = random.uniform(-ratio, ratio)
    h, w = img.shape[:2]
    to_shift = h*ratio
    if ratio > 0:
        img = img[:int(h-to_shift), :, :]
    if ratio < 0:
        img = img[int(-1*to_shift):, :, :]
    img = fill(img, h, w)
    return img

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/red/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_vertical = vertical_shift(img, 0.7)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\red\\"+img_name+'_vertical.jpg',img_vertical)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/pink/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_vertical = vertical_shift(img, 0.7)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\pink\\"+img_name+'_vertical.jpg',img_vertical)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/white/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_vertical = vertical_shift(img, 0.7)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\white\\"+img_name+'_vertical.jpg',img_vertical)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/wrong/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_vertical = vertical_shift(img, 0.7)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\wrong\\"+img_name+'_vertical.jpg',img_vertical)

# %%
def brightness(img, low, high):
    value = random.uniform(low, high)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    hsv = np.array(hsv, dtype = np.float64)
    hsv[:,:,1] = hsv[:,:,1]*value
    hsv[:,:,1][hsv[:,:,1]>255]  = 255
    hsv[:,:,2] = hsv[:,:,2]*value 
    hsv[:,:,2][hsv[:,:,2]>255]  = 255
    hsv = np.array(hsv, dtype = np.uint8)
    img = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    return img

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/red/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_brightness = brightness(img, 0.5,3)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\red\\"+img_name+'_bright.jpg',img_brightness)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/pink/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_brightness = brightness(img, 0.5,3)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\pink\\"+img_name+'_bright.jpg',img_brightness)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/white/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_brightness = brightness(img, 0.5,3)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\white\\"+img_name+'_bright.jpg',img_brightness)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/wrong/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_brightness = brightness(img, 0.5,3)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\wrong\\"+img_name+'_bright.jpg',img_brightness)

# %%
def fill(img, h, w):
    img = cv2.resize(img, (h, w), cv2.INTER_CUBIC)
    return img
def zoom(img, value):
    if value > 1 or value < 0:
        #print('Value for zoom should be less than 1 and greater than 0')
        return img
    value = random.uniform(value, 1)
    h, w = img.shape[:2]
    h_taken = int(value*h)
    w_taken = int(value*w)
    h_start = random.randint(0, h-h_taken)
    w_start = random.randint(0, w-w_taken)
    img = img[h_start:h_start+h_taken, w_start:w_start+w_taken, :]
    img = fill(img, h, w)
    return img

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/red/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_zoom = zoom(img, 0.5)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\red\\"+img_name+'_zoomed.jpg',img_zoom)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/pink/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_zoom = zoom(img, 0.5)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\pink\\"+img_name+'_zoomed.jpg',img_zoom)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/white/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_zoom = zoom(img, 0.5)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\white\\"+img_name+'_zoomed.jpg',img_zoom)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/wrong/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_zoom = zoom(img, 0.5)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\wrong\\"+img_name+'_zoomed.jpg',img_zoom)

# %%
def channel_shift(img, value):
    value = int(random.uniform(-value, value))
    img = img + value
    img[:,:,:][img[:,:,:]>255]  = 255
    img[:,:,:][img[:,:,:]<0]  = 0
    img = img.astype(np.uint8)
    return img

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/red/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_channel = channel_shift(img, 0.5)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\red\\"+img_name+'_channel.jpg',img_channel)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/pink/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_channel = channel_shift(img, 0.5)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\pink\\"+img_name+'_channel.jpg',img_channel)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/white/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_channel = channel_shift(img, 0.5)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\white\\"+img_name+'_channel.jpg',img_channel)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/wrong/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_channel = channel_shift(img, 0.5)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\wrong\\"+img_name+'_channel.jpg',img_channel)

# %%
def horizontal_flip(img, flag):
    if flag:
        return cv2.flip(img, 1)
    else:
        return img

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/red/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_horizontal_flip = horizontal_flip(img, True)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\red\\"+img_name+'_horizontal_flip.jpg',img_horizontal_flip)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/pink/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_horizontal_flip = horizontal_flip(img, True)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\pink\\"+img_name+'_horizontal_flip.jpg',img_horizontal_flip)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/white/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_horizontal_flip = horizontal_flip(img, True)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\white\\"+img_name+'_horizontal_flip.jpg',img_horizontal_flip)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/wrong/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_horizontal_flip = horizontal_flip(img, True)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\wrong\\"+img_name+'_horizontal_flip.jpg',img_horizontal_flip)

# %%
def vertical_flip(img, flag):
    if flag:
        return cv2.flip(img, 0)
    else:
        return img

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/red/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_vertical_flip = vertical_flip(img, True)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\red\\"+img_name+'_vertical_flip.jpg',img_vertical_flip)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/pink/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_vertical_flip = vertical_flip(img, True)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\pink\\"+img_name+'_vertical_flip.jpg',img_vertical_flip)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/white/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_vertical_flip = vertical_flip(img, True)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\white\\"+img_name+'_vertical_flip.jpg',img_vertical_flip)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/wrong/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_vertical_flip = vertical_flip(img, True)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\wrong\\"+img_name+'_vertical_flip.jpg',img_vertical_flip)

# %%
def fill_mode(img, left, right):
    nearest = cv2.copyMakeBorder(img, 0, 0, left, right, cv2.BORDER_REPLICATE)
    reflect = cv2.copyMakeBorder(img, 0, 0, left, right, cv2.BORDER_REFLECT)
    wrap = cv2.copyMakeBorder(img, 0, 0, left, right, cv2.BORDER_WRAP)
    constant= cv2.copyMakeBorder(img, 0, 0, left, right, cv2.BORDER_CONSTANT,value=(255, 0, 0))
    
    plt.subplot(221),plt.imshow(nearest,'gray'),plt.title('NEAREST'),plt.axis('off')
    plt.subplot(222),plt.imshow(reflect,'gray'),plt.title('REFLECT'),plt.axis('off')
    plt.subplot(223),plt.imshow(wrap,'gray'),plt.title('WRAP'),plt.axis('off')
    plt.subplot(224),plt.imshow(constant,'gray'),plt.title('CONSTANT'),plt.axis('off')
    #return img
    
def horizontal_shift_mode(img, ratio):
    if ratio > 1 or ratio < 0:
        #print('Value for horizontal shift should be less than 1 and greater than 0')
        return img
    ratio = random.uniform(-ratio, ratio)
    h, w = img.shape[:2]
    to_shift = int(w*ratio)
    if ratio > 0:
        img = img[:, :w-to_shift, :]
        fill_mode(img, to_shift, 0)
    if ratio < 0:
        img = img[:, -1*to_shift:, :]
        fill_mode(img, 0, -1*to_shift)
    
    return img

# %%
from matplotlib import pyplot as plt


files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/red/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_fill_mode = horizontal_shift_mode(img, 0.8)
    #print(file)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    #cv2.imwrite("C:/Users/USER/Downloads/test/"+img_name+'_fill_mode.jpg',img_fill_mode)
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\red\\"+img_name+'_fill_mode.jpg',img_fill_mode)

# %%
from matplotlib import pyplot as plt


files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/pink/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_fill_mode = horizontal_shift_mode(img, 0.8)
    #print(file)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    #cv2.imwrite("C:/Users/USER/Downloads/test/"+img_name+'_fill_mode.jpg',img_fill_mode)
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\pink\\"+img_name+'_fill_mode.jpg',img_fill_mode)

# %%
from matplotlib import pyplot as plt


files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/white/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_fill_mode = horizontal_shift_mode(img, 0.8)
    #print(file)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    #cv2.imwrite("C:/Users/USER/Downloads/test/"+img_name+'_fill_mode.jpg',img_fill_mode)
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\white\\"+img_name+'_fill_mode.jpg',img_fill_mode)

# %%
from matplotlib import pyplot as plt


files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/wrong/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_fill_mode = horizontal_shift_mode(img, 0.8)
    #print(file)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
     
    #cv2.imwrite("C:/Users/USER/Downloads/test/"+img_name+'_fill_mode.jpg',img_fill_mode)
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\wrong\\"+img_name+'_fill_mode.jpg',img_fill_mode)

# %%
#type(cv2.imread('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/red/*.jpg'))

# %%
def rotation(img, angle):
    angle = int(random.uniform(-angle, angle))
    h, w = img.shape[:2]
    M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), angle, 1)
    img = cv2.warpAffine(img, M, (w, h))
    return img

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/red/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_rotation = rotation(img, 30)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\red\\"+img_name+'_rotated.jpg',img_rotation)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/pink/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_rotation = rotation(img, 30)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\pink\\"+img_name+'_rotated.jpg',img_rotation)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/white/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_rotation = rotation(img, 30)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0] 
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\white\\"+img_name+'_rotated.jpg',img_rotation)

# %%
files = glob.glob('C:/Users/USER/Downloads/Hibiscus Classification App - Update 2 - Dataset/Images/Collected/wrong/*.jpg')
    
for file in files:
    img = cv2.imread(file)
    img_rotation = rotation(img, 30)
    img_name = file.split('\\')[-1]
    img_name = img_name.split('.')[0]
    cv2.imwrite("C:\\Users\\USER\\Downloads\\Hibiscus Classification App - Update 2 - Dataset\\Images\\Augmented\\wrong\\"+img_name+'_rotated.jpg',img_rotation)
